# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib import gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
import scipy.io as sio
from scipy.io import loadmat

import IERS_functions as IERS

# %%
'''
--------------------------------------------------------------------------
(c) TU Delft
This is the main script that will assist the student on how to answer 
question 2 of Part 2 of the assignment

It loads the horizontal component of a ground acceleration signal from 
the directory: 'Python for Project Work SRE_Part 2/IERS/Signal'. The folder Signal
is initially empty. The student has to put there signals from the previous
question.

Following that, the script calculates the elastic response spectrum, the
indirect inelastic rersponse spectrum (by applying the Newmark-Hall (1982) 
Ry – mu – Tn relationshipe) and the direct inelasic response spectrum.

The solver that is used to calculate the response of the elastic and the
elastoplasic SDoF systems is the Newmark beta integration.
The student is asked to complete the script by filling in the lines
indicated by "<----fill in equation here".

You will have to write your own code for plotting purposes.
--------------------------------------------------------------------------
                         initialisation 
--------------------------------------------------------------------------

One can choose for 'file' either 1 or 2, etc. , such that a specific signal
will be analysed.

Note that the student may have to make changes to the code in order to answer the various questions.
'''
A = 5
B = 8
C = 2
D = 9
E = 6
F = 1
G = 5

file = 1                                          # <------ fill in equation here

FilePath = 'Signal'
FilePath_full = './' + FilePath + '/'
signal_files = []
for root, _, files_in_root in os.walk(FilePath_full):
    for fname in files_in_root:
        if fname.lower().endswith('.txt'):
            signal_files.append(os.path.join(root, fname))
signal_files = sorted(signal_files)
if len(signal_files) == 0:
    raise FileNotFoundError('No .txt signal files found in Signal folder')
if file < 1 or file > len(signal_files):
    raise ValueError(f"'file' must be between 1 and {len(signal_files)}")
FileName = signal_files[file-1]
with open(FileName, 'r') as fileID:
    info = np.loadtxt(fileID)

NPTS = len(info[:,0])
Dt = info[1,0]
ag_time = info[:,1]


'''
Calls the function that calculates the elastic response spectrum.
The student is advised to open the function and have a look at it.
The student has to specify the damping ratio "xi" based on Assignment 3
instructions.
'''
xi = 0.04+C/1000                                    # <------ fill in equation here
SA_el,F_el =  IERS.fnc_Elastic_Response_Spectrum(ag_time,Dt,NPTS,xi)

'''
--------------------------------------------------------------------------
                         Question 2
--------------------------------------------------------------------------
Here the student is asked to calculate the constant ductilty inelastic
acceleration spectra in two ways:
    1) indirect way, by applying the Newmark-Hall (1982) Ry – mu – Tn
    relationship on the Elastic acceleration reponse spectrum
    2) direct way, following the steps of the iterative procedure
First of all the student has to specify the "mu"
'''
mu = max(1.7 + D/100, 1.7 + F/100)                    # <------ fill in equation here

'''
-- Indirect inelastic acceleration response spectrum --
In the following lines fill in the
quantities of the branched of Ry that are missing (Newmark-Hall Ry – mu – Tn relationship (1982))

Please create the function that defines the value of Ry
'''

# initialisation 
Tn = np.zeros(201)
Ry = np.zeros(201)

for i in range(201):
    Tn[i] = (i-1) * 0.02
    if Tn[i] <= 0.05:
        Ry[i] = 1                   # <------ fill in equation here 
    elif Tn[i] > 0.05 and Tn[i] <= 0.12:
        Ry[i] = 1 + ((np.sqrt(2*mu-1)-1)/(0.12-0.05))*(Tn[i]-0.05)  # linearly interpolate between 0.05-12s
    elif Tn[i] > 0.12 and Tn[i] <= 0.5:
        Ry[i] = np.sqrt(2*mu-1)
    elif Tn[i] > 0.5 and Tn[i] <= 1:
        Ry[i] = (2*mu - 1)**(1/2)                # <------ fill in equation here
    elif Tn[i] > 1:
        Ry[i] = mu                   # <------ fill in equation here

# Calculation of indirect inelastic acceleration response spectrum as a
# function of the elastic response spectrum derived previously.
SA_in_ind = np.zeros(201)

for i in range(201):
    SA_in_ind[i] = Ry[i] * SA_el[i]                  # <------ fill in equation here

'''
-- Direct inelastic acceleration response spectrum
The following Python function calculates the direct inelastic response spectrum for the chosen time history
'''
SA_in_dir =  IERS.fnc_Direct_Inel_Resp_Spec(ag_time,Dt,NPTS,xi,mu,SA_el,F_el);
# Out:
# Calculating for Tn = 0.02
# Calculating for Tn = 0.04
# Calculating for Tn = 0.06
# Calculating for Tn = 0.08
# Calculating for Tn = 0.1
# Calculating for Tn = 0.12
# Calculating for Tn = 0.14
# Calculating for Tn = 0.16
# Calculating for Tn = 0.18
# Calculating for Tn = 0.2
# Calculating for Tn = 0.22
# Calculating for Tn = 0.24
# Calculating for Tn = 0.26
# Calculating for Tn = 0.28
# Calculating for Tn = 0.3
# Calculating for Tn = 0.32
# Calculating for Tn = 0.34
# Calculating for Tn = 0.36
# Calculating for Tn = 0.38
# Calculating for Tn = 0.4
# Calculating for Tn = 0.42
# Calculating for Tn = 0.44
# Calculating for Tn = 0.46
# Calculating for Tn = 0.48
# Calculating for Tn = 0.5
# Calculating for Tn = 0.52
# Calculating for Tn = 0.54
# Calculating for Tn = 0.56
# Calculating for Tn = 0.58
# Calculating for Tn = 0.6
# Calculating for Tn = 0.62
# Calculating for Tn = 0.64
# Calculating for Tn = 0.66
# Calculating for Tn = 0.68
# Calculating for Tn = 0.7000000000000001
# Calculating for Tn = 0.72
# Calculating for Tn = 0.74
# Calculating for Tn = 0.76
# Calculating for Tn = 0.78
# Calculating for Tn = 0.8
# Calculating for Tn = 0.8200000000000001
# Calculating for Tn = 0.84
# Calculating for Tn = 0.86
# Calculating for Tn = 0.88
# Calculating for Tn = 0.9
# Calculating for Tn = 0.92
# Calculating for Tn = 0.9400000000000001
# Calculating for Tn = 0.96
# Calculating for Tn = 0.98
# Calculating for Tn = 1.0
# Calculating for Tn = 1.02
# Calculating for Tn = 1.04
# Calculating for Tn = 1.06
# Calculating for Tn = 1.08
# Calculating for Tn = 1.1
# Calculating for Tn = 1.12
# Calculating for Tn = 1.1400000000000001
# Calculating for Tn = 1.16
# Calculating for Tn = 1.18
# Calculating for Tn = 1.2
# Calculating for Tn = 1.22
# Calculating for Tn = 1.24
# Calculating for Tn = 1.26
# Calculating for Tn = 1.28
# Calculating for Tn = 1.3
# Calculating for Tn = 1.32
# Calculating for Tn = 1.34
# Calculating for Tn = 1.36
# Calculating for Tn = 1.3800000000000001
# Calculating for Tn = 1.4000000000000001
# Calculating for Tn = 1.42
# Calculating for Tn = 1.44
# Calculating for Tn = 1.46
# Calculating for Tn = 1.48
# Calculating for Tn = 1.5
# Calculating for Tn = 1.52
# Calculating for Tn = 1.54
# Calculating for Tn = 1.56
# Calculating for Tn = 1.58
# Calculating for Tn = 1.6
# Calculating for Tn = 1.62
# Calculating for Tn = 1.6400000000000001
# Calculating for Tn = 1.6600000000000001
# Calculating for Tn = 1.68
# Calculating for Tn = 1.7
# Calculating for Tn = 1.72
# Calculating for Tn = 1.74
# Calculating for Tn = 1.76
# Calculating for Tn = 1.78
# Calculating for Tn = 1.8
# Calculating for Tn = 1.82
# Calculating for Tn = 1.84
# Calculating for Tn = 1.86
# Calculating for Tn = 1.8800000000000001
# Calculating for Tn = 1.9000000000000001
# Calculating for Tn = 1.92
# Calculating for Tn = 1.94
# Calculating for Tn = 1.96
# Calculating for Tn = 1.98
# Calculating for Tn = 2.0
# Calculating for Tn = 2.02
# Calculating for Tn = 2.04
# Calculating for Tn = 2.06
# Calculating for Tn = 2.08
# Calculating for Tn = 2.1
# Calculating for Tn = 2.12
# Calculating for Tn = 2.14
# Calculating for Tn = 2.16
# Calculating for Tn = 2.18
# Calculating for Tn = 2.2
# Calculating for Tn = 2.22
# Calculating for Tn = 2.24
# Calculating for Tn = 2.2600000000000002
# Calculating for Tn = 2.2800000000000002
# Calculating for Tn = 2.3000000000000003
# Calculating for Tn = 2.32
# Calculating for Tn = 2.34
# Calculating for Tn = 2.36
# Calculating for Tn = 2.38
# Calculating for Tn = 2.4
# Calculating for Tn = 2.42
# Calculating for Tn = 2.44
# Calculating for Tn = 2.46
# Calculating for Tn = 2.48
# Calculating for Tn = 2.5
# Calculating for Tn = 2.52
# Calculating for Tn = 2.54
# Calculating for Tn = 2.56
# Calculating for Tn = 2.58
# Calculating for Tn = 2.6
# Calculating for Tn = 2.62
# Calculating for Tn = 2.64
# Calculating for Tn = 2.66
# Calculating for Tn = 2.68
# Calculating for Tn = 2.7
# Calculating for Tn = 2.72
# Calculating for Tn = 2.74
# Calculating for Tn = 2.7600000000000002
# Calculating for Tn = 2.7800000000000002
# Calculating for Tn = 2.8000000000000003
# Calculating for Tn = 2.82
# Calculating for Tn = 2.84
# Calculating for Tn = 2.86
# Calculating for Tn = 2.88
# Calculating for Tn = 2.9
# Calculating for Tn = 2.92
# Calculating for Tn = 2.94
# Calculating for Tn = 2.96
# Calculating for Tn = 2.98
# Calculating for Tn = 3.0
# Calculating for Tn = 3.02
# Calculating for Tn = 3.04
# Calculating for Tn = 3.06
# Calculating for Tn = 3.08
# Calculating for Tn = 3.1
# Calculating for Tn = 3.12
# Calculating for Tn = 3.14
# Calculating for Tn = 3.16
# Calculating for Tn = 3.18
# Calculating for Tn = 3.2
# Calculating for Tn = 3.22
# Calculating for Tn = 3.24
# Calculating for Tn = 3.2600000000000002
# Calculating for Tn = 3.2800000000000002
# Calculating for Tn = 3.3000000000000003
# Calculating for Tn = 3.3200000000000003
# Calculating for Tn = 3.34
# Calculating for Tn = 3.36
# Calculating for Tn = 3.38
# Calculating for Tn = 3.4
# Calculating for Tn = 3.42
# Calculating for Tn = 3.44
# Calculating for Tn = 3.46
# Calculating for Tn = 3.48
# Calculating for Tn = 3.5
# Calculating for Tn = 3.52
# Calculating for Tn = 3.54
# Calculating for Tn = 3.56
# Calculating for Tn = 3.58
# Calculating for Tn = 3.6
# Calculating for Tn = 3.62
# Calculating for Tn = 3.64
# Calculating for Tn = 3.66
# Calculating for Tn = 3.68
# Calculating for Tn = 3.7
# Calculating for Tn = 3.72
# Calculating for Tn = 3.74
# Calculating for Tn = 3.7600000000000002
# Calculating for Tn = 3.7800000000000002
# Calculating for Tn = 3.8000000000000003
# Calculating for Tn = 3.8200000000000003
# Calculating for Tn = 3.84
# Calculating for Tn = 3.86
# Calculating for Tn = 3.88
# Calculating for Tn = 3.9
# Calculating for Tn = 3.92
# Calculating for Tn = 3.94
# Calculating for Tn = 3.96
# Calculating for Tn = 3.98
# Calculating for Tn = 4.0
# Done

# %%
plt.figure(figsize=(10,6))
plt.plot(Tn, SA_in_ind, label='Indirect Inelastic')
plt.xlabel('Natural Period (s)')
plt.ylabel('Spectral Acceleration [g]')
plt.title('Indirect Inelastic Response Spectra')
plt.legend()
plt.grid()

plt.figure(figsize=(10,6))
plt.plot(Tn, SA_in_dir, label='Direct Inelastic')
plt.xlabel('Natural Period (s)')
plt.ylabel('Spectral Acceleration [g]')
plt.title('Direct Inelastic Response Spectra')
plt.legend()
plt.grid()
